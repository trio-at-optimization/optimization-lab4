# %%
import sys
sys.path.append('../')

import numpy as np
import helper
from scipy.optimize import LinearConstraint, NonlinearConstraint

# %%
def fun(x):
    return x[0] ** 2 + x[1] ** 2

def rosen(x):
    return (1 - x[0]) ** 2 + 100 * (x[1] - x[0] ** 2) ** 2

# Задаем линейные ограничения
x0 = (-0.0, 0.8)
x_lin = np.linspace(-1.6, 1.3, 400, dtype=float)
y_lin = np.linspace(-0.1, 1.1, 400, dtype=float)

# Задаем границы переменных
bounds = ((-1, 1), (-1, 1))

# Без ограничений
helper.minimize_and_output(
    rosen, x0, x_lin, y_lin,
    'trust-constr', 'trust-constr', 'trust-constr with non-linear constaints', 
    constraints=None, bounds=bounds, manual_history=True, nth=3
)

# С нелинейными ограничениями
nonlinear_constraints = [NonlinearConstraint(lambda x: (x[0] ** 2) / 3 + (x[1] ** 2) / 0.5 - 0.6, 0.5, np.inf)]
helper.minimize_and_output(
    rosen, x0, x_lin, y_lin,
    'trust-constr', 'trust-constr', 'trust-constr with non-linear constaints', 
    constraints=nonlinear_constraints, bounds=bounds, manual_history=True, nth=3
)
# Out:
# /Users/mac/JetBrains_Projects/PycharmProjects/MetOpt/venv/lib/python3.9/site-packages/scipy/optimize/_hessian_update_strategy.py:182: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   warn('delta_grad == 0.0. Check if the approximated '
# trust-constr with non-linear constaints
# trust-constr    ==>   0.000001 in [  0.998788,   0.997573] in 58 steps.
# /Users/mac/JetBrains_Projects/PycharmProjects/MetOpt/Sources/AT1/../helper/package_AT1/module_compare_and_output.py:27: UserWarning: linewidths is ignored by contourf
#   cf = ax.contourf(file_info_3d.X, file_info_3d.Y, file_info_3d.Z, antialiased=True, linewidths=1.7)
# /Users/mac/JetBrains_Projects/PycharmProjects/MetOpt/venv/lib/python3.9/site-packages/scipy/optimize/_hessian_update_strategy.py:182: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   warn('delta_grad == 0.0. Check if the approximated '
# /Users/mac/JetBrains_Projects/PycharmProjects/MetOpt/Sources/AT1/../helper/package_AT1/module_compare_and_output.py:27: UserWarning: linewidths is ignored by contourf
#   cf = ax.contourf(file_info_3d.X, file_info_3d.Y, file_info_3d.Z, antialiased=True, linewidths=1.7)
# trust-constr with non-linear constaints
# trust-constr    ==>   0.000001 in [  0.998787,   0.997571] in 44 steps.

# %%
x0 = (-0.0, 0.8)
x_lin = np.linspace(-1.6, 1.3, 400, dtype=float)
y_lin = np.linspace(-0.1, 1.1, 400, dtype=float)


# Без ограничений
helper.minimize_and_output(
    rosen, x0, x_lin, y_lin,
    'trust-constr', 'trust-constr', 'trust-constr with non-linear constaints', 
    constraints=None, bounds=bounds, manual_history=True, nth=3
)

# С нелинейными ограничениями
linear_constraints = [LinearConstraint(np.array([0.1, 1]), lb=0.78)]
helper.minimize_and_output(
    rosen, x0, x_lin, y_lin,
    'trust-constr', 'trust-constr', 'trust-constr with non-linear constaints', 
    constraints=linear_constraints, bounds=bounds, manual_history=True, nth=3
)
# Out:
# /Users/mac/JetBrains_Projects/PycharmProjects/MetOpt/venv/lib/python3.9/site-packages/scipy/optimize/_hessian_update_strategy.py:182: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   warn('delta_grad == 0.0. Check if the approximated '
# /Users/mac/JetBrains_Projects/PycharmProjects/MetOpt/Sources/AT1/../helper/package_AT1/module_compare_and_output.py:27: UserWarning: linewidths is ignored by contourf
#   cf = ax.contourf(file_info_3d.X, file_info_3d.Y, file_info_3d.Z, antialiased=True, linewidths=1.7)
# trust-constr with non-linear constaints
# trust-constr    ==>   0.000001 in [  0.998788,   0.997573] in 58 steps.
# trust-constr with non-linear constaints
# trust-constr    ==>   0.000007 in [  0.997298,   0.994596] in 35 steps.
# /Users/mac/JetBrains_Projects/PycharmProjects/MetOpt/Sources/AT1/../helper/package_AT1/module_compare_and_output.py:27: UserWarning: linewidths is ignored by contourf
#   cf = ax.contourf(file_info_3d.X, file_info_3d.Y, file_info_3d.Z, antialiased=True, linewidths=1.7)

# %%
def f_tanga(x, _=None):
    return sum([xi ** 4 - 16 * xi ** 2 + 5 * xi for xi in x])


x0 = (-3.0, 0.0)
x_lin = np.linspace(-5, 5, 1000, dtype=float)
y_lin = np.linspace(-5, 5, 1000, dtype=float)


# Без ограничений
helper.minimize_and_output(
    f_tanga, x0, x_lin, y_lin,
    'trust-constr', 'trust-constr', 'trust-constr with non-linear constaints', 
    constraints=None, bounds=bounds, manual_history=True
)

# С линейными ограничениями
linear_constraints = [LinearConstraint(np.array([1, 0]), ub=-4.5)]
helper.minimize_and_output(
    f_tanga, x0, x_lin, y_lin,
    'trust-constr', 'trust-constr', 'trust-constr with non-linear constaints', 
    constraints=linear_constraints, bounds=bounds, manual_history=True, nth=3
)
# Out:
# trust-constr with non-linear constaints
# trust-constr    ==> -39.991961 in [ -0.999878,  -0.999878] in 10 steps.
# /Users/mac/JetBrains_Projects/PycharmProjects/MetOpt/Sources/AT1/../helper/package_AT1/module_compare_and_output.py:27: UserWarning: linewidths is ignored by contourf
#   cf = ax.contourf(file_info_3d.X, file_info_3d.Y, file_info_3d.Z, antialiased=True, linewidths=1.7)
# /Users/mac/JetBrains_Projects/PycharmProjects/MetOpt/venv/lib/python3.9/site-packages/scipy/optimize/_trustregion_constr/projections.py:181: UserWarning: Singular Jacobian matrix. Using SVD decomposition to perform the factorizations.
#   warn('Singular Jacobian matrix. Using SVD decomposition to ' +
# /Users/mac/JetBrains_Projects/PycharmProjects/MetOpt/venv/lib/python3.9/site-packages/scipy/optimize/_hessian_update_strategy.py:182: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   warn('delta_grad == 0.0. Check if the approximated '
# trust-constr with non-linear constaints
# trust-constr    ==> -97.558594 in [ -2.750000,  -1.000000] in 419 steps.
# /Users/mac/JetBrains_Projects/PycharmProjects/MetOpt/Sources/AT1/../helper/package_AT1/module_compare_and_output.py:27: UserWarning: linewidths is ignored by contourf
#   cf = ax.contourf(file_info_3d.X, file_info_3d.Y, file_info_3d.Z, antialiased=True, linewidths=1.7)
